# %%
import chess

board = chess.Board()

# %%
def move_generation_test(depth):
    if(depth == 0):
        return 1
  
    moves = list(board.generate_legal_moves())
    numPositions = 0

    for move in moves:
        board.push(move)
        numPositions += move_generation_test(depth -1)
        board.pop()
        
    return numPositions

for i in range(7):
    print("Depth: {0} = {1} Nodes".format(i, move_generation_test(i)))


# Wypisz liczbę węzłów wygenerowanych dla każdej głębokości od 0 do 6
#
# To pokaże, jak liczba legalnych ruchów rośnie wraz z głębokością
# Oczekiwany wynik:
# Depth: 0 = 1 Nodes
# Depth: 1 = 20 Nodes
# Depth: 2 = 400 Nodes
# Depth: 3 = 8902 Nodes
# Depth: 4 = 197281 Nodes   
# Depth: 5 = 4865609 Nodes
# Depth: 6 = 119060324 Nodes
# Out:
# Depth: 0 = 1 Nodes
# Depth: 1 = 20 Nodes
# Depth: 2 = 400 Nodes
# Depth: 3 = 8902 Nodes
# Depth: 4 = 197281 Nodes
# Depth: 5 = 4865609 Nodes
# Depth: 6 = 119060324 Nodes
