# %%
import torch
import torch.nn as nn 
import torch.optim as optim 
from torch.utils.data import DataLoader, random_split
from data_manager import load_data, get_data_shapes
# %load_ext autoreload
# %autoreload 2

# %%
X, y, num_games = load_data(limit=800000)
print("Ilość ewaluacji pozycji:", num_games)
# Out:
# Przetwarzanie pozycji:   0%|          | 0/800000 [00:00<?, ?it/s]
# Ilość ewaluacji pozycji: 800000

# %%
get_data_shapes(X,y)
# Out:
# {'X_shape': (800000, 8, 8, 18),
#  'y_shape': (800000,),
#  'X_dtype': dtype('float32'),
#  'y_dtype': dtype('float32'),
#  'X_min': np.float32(0.0),
#  'X_max': np.float32(1.0),
#  'y_min': np.float32(-1.0),
#  'y_max': np.float32(1.0),
#  'y_unique': 2001}

# %%
print(y[:2])
# Out:
# [ 0.   -0.01]

# %%
from dataset import ChessDataset
from model import SmallResNetValue as Model

dataset = ChessDataset(X, y)

train_size = int(0.8 * len(dataset))

val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])


train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

torch.manual_seed(42)

model = Model().to(device)
model
# Out:
# Using device: cuda
# SmallResNetValue(
#   (conv1): Conv2d(18, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc1): Linear(in_features=256, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=1, bias=True)
#   (relu): ReLU(inplace=True)
#   (tanh): Tanh()
# )

# %%
import csv

optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.MSELoss() # ew. nn.L1Loss() lub nn.SmoothL1Loss()
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, factor=0.5, patience=5
)

num_epochs = 100
model_name = "cn2_bn2_rlrop"
model_type = "Default + 1x Conv2d(128,256) 3x BatchNorm2d(64) and 128, ReduceLROnPlateau"

description = f"Epochs: {num_epochs}, Lr:{optimizer.param_groups[0]['lr']}, Model: {model_type}"

with open(f"../../charts/value_network/{model_name}.csv", "w", newline='') as csvfile:
    csvfile.write(f"# {description}\n")
    writer = csv.writer(csvfile)
    writer.writerow(["epoch", "train_loss", "val_loss"])

    for epoch in range(num_epochs):
        # ----- Trening -----
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            running_loss += loss.item()
        avg_train_loss = running_loss / len(train_loader)

        # ----- Walidacja -----
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
        avg_val_loss = val_loss / len(val_loader)

        # ----- Scheduler -----
        scheduler.step(avg_val_loss)

        # ----- Logi -----
        writer.writerow([epoch + 1, avg_train_loss, avg_val_loss])
        print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1/100 | Train Loss: 0.0731 | Val Loss: 0.0690
# Epoch 2/100 | Train Loss: 0.0601 | Val Loss: 0.0585
# Epoch 3/100 | Train Loss: 0.0528 | Val Loss: 0.0497
# Epoch 4/100 | Train Loss: 0.0476 | Val Loss: 0.0552
# Epoch 5/100 | Train Loss: 0.0432 | Val Loss: 0.0456
# Epoch 6/100 | Train Loss: 0.0395 | Val Loss: 0.0462
# Epoch 7/100 | Train Loss: 0.0363 | Val Loss: 0.0410
# Epoch 8/100 | Train Loss: 0.0334 | Val Loss: 0.0403
# Epoch 9/100 | Train Loss: 0.0309 | Val Loss: 0.0477
# Epoch 10/100 | Train Loss: 0.0285 | Val Loss: 0.0408
# Epoch 11/100 | Train Loss: 0.0267 | Val Loss: 0.0390
# Epoch 12/100 | Train Loss: 0.0249 | Val Loss: 0.0383
# Epoch 13/100 | Train Loss: 0.0233 | Val Loss: 0.0331
# Epoch 14/100 | Train Loss: 0.0219 | Val Loss: 0.0314
# Epoch 15/100 | Train Loss: 0.0208 | Val Loss: 0.0316
# Epoch 16/100 | Train Loss: 0.0197 | Val Loss: 0.0348
# Epoch 17/100 | Train Loss: 0.0187 | Val Loss: 0.0323
# Epoch 18/100 | Train Loss: 0.0178 | Val Loss: 0.0617
# Epoch 19/100 | Train Loss: 0.0170 | Val Loss: 0.0470
# Epoch 20/100 | Train Loss: 0.0163 | Val Loss: 0.0289
# Epoch 21/100 | Train Loss: 0.0157 | Val Loss: 0.0318
# Epoch 22/100 | Train Loss: 0.0151 | Val Loss: 0.0304
# Epoch 23/100 | Train Loss: 0.0146 | Val Loss: 0.0322
# Epoch 24/100 | Train Loss: 0.0140 | Val Loss: 0.0276
# Epoch 25/100 | Train Loss: 0.0135 | Val Loss: 0.0277
# Epoch 26/100 | Train Loss: 0.0131 | Val Loss: 0.0309
# Epoch 27/100 | Train Loss: 0.0127 | Val Loss: 0.0291
# Epoch 28/100 | Train Loss: 0.0123 | Val Loss: 0.0273
# Epoch 29/100 | Train Loss: 0.0120 | Val Loss: 0.0259
# Epoch 30/100 | Train Loss: 0.0117 | Val Loss: 0.0299
# Epoch 31/100 | Train Loss: 0.0114 | Val Loss: 0.0257
# Epoch 32/100 | Train Loss: 0.0111 | Val Loss: 0.0280
# Epoch 33/100 | Train Loss: 0.0109 | Val Loss: 0.0259
# Epoch 34/100 | Train Loss: 0.0107 | Val Loss: 0.0348
# Epoch 35/100 | Train Loss: 0.0104 | Val Loss: 0.0274
# Epoch 36/100 | Train Loss: 0.0102 | Val Loss: 0.0258
# Epoch 37/100 | Train Loss: 0.0099 | Val Loss: 0.0261
# Epoch 38/100 | Train Loss: 0.0080 | Val Loss: 0.0255
# Epoch 39/100 | Train Loss: 0.0075 | Val Loss: 0.0246
# Epoch 40/100 | Train Loss: 0.0073 | Val Loss: 0.0244
# Epoch 41/100 | Train Loss: 0.0071 | Val Loss: 0.0249
# Epoch 42/100 | Train Loss: 0.0070 | Val Loss: 0.0241
# Epoch 43/100 | Train Loss: 0.0069 | Val Loss: 0.0253
# Epoch 44/100 | Train Loss: 0.0068 | Val Loss: 0.0237
# Epoch 45/100 | Train Loss: 0.0067 | Val Loss: 0.0237
# Epoch 46/100 | Train Loss: 0.0066 | Val Loss: 0.0233
# Epoch 47/100 | Train Loss: 0.0065 | Val Loss: 0.0241
# Epoch 48/100 | Train Loss: 0.0064 | Val Loss: 0.0235
# Epoch 49/100 | Train Loss: 0.0063 | Val Loss: 0.0287
# Epoch 50/100 | Train Loss: 0.0063 | Val Loss: 0.0242
# Epoch 51/100 | Train Loss: 0.0062 | Val Loss: 0.0236
# Epoch 52/100 | Train Loss: 0.0061 | Val Loss: 0.0247
# Epoch 53/100 | Train Loss: 0.0053 | Val Loss: 0.0230
# Epoch 54/100 | Train Loss: 0.0052 | Val Loss: 0.0249
# Epoch 55/100 | Train Loss: 0.0051 | Val Loss: 0.0231
# Epoch 56/100 | Train Loss: 0.0051 | Val Loss: 0.0231
# Epoch 57/100 | Train Loss: 0.0050 | Val Loss: 0.0238
# Epoch 58/100 | Train Loss: 0.0050 | Val Loss: 0.0232
# Epoch 59/100 | Train Loss: 0.0049 | Val Loss: 0.0233
# Epoch 60/100 | Train Loss: 0.0046 | Val Loss: 0.0234
# Epoch 61/100 | Train Loss: 0.0045 | Val Loss: 0.0232
# Epoch 62/100 | Train Loss: 0.0045 | Val Loss: 0.0230
# Epoch 63/100 | Train Loss: 0.0045 | Val Loss: 0.0235
# Epoch 64/100 | Train Loss: 0.0044 | Val Loss: 0.0232
# Epoch 65/100 | Train Loss: 0.0044 | Val Loss: 0.0230
# Epoch 66/100 | Train Loss: 0.0043 | Val Loss: 0.0232
# Epoch 67/100 | Train Loss: 0.0042 | Val Loss: 0.0231
# Epoch 68/100 | Train Loss: 0.0042 | Val Loss: 0.0233
# Epoch 69/100 | Train Loss: 0.0042 | Val Loss: 0.0233
# Epoch 70/100 | Train Loss: 0.0042 | Val Loss: 0.0233
# Epoch 71/100 | Train Loss: 0.0042 | Val Loss: 0.0231
# Epoch 72/100 | Train Loss: 0.0041 | Val Loss: 0.0232
# Epoch 73/100 | Train Loss: 0.0041 | Val Loss: 0.0232
# Epoch 74/100 | Train Loss: 0.0041 | Val Loss: 0.0232
# Epoch 75/100 | Train Loss: 0.0040 | Val Loss: 0.0233
# Epoch 76/100 | Train Loss: 0.0040 | Val Loss: 0.0231
# Epoch 77/100 | Train Loss: 0.0040 | Val Loss: 0.0232
# Epoch 78/100 | Train Loss: 0.0040 | Val Loss: 0.0231
# Epoch 79/100 | Train Loss: 0.0040 | Val Loss: 0.0232
# Epoch 80/100 | Train Loss: 0.0040 | Val Loss: 0.0233
# Epoch 81/100 | Train Loss: 0.0040 | Val Loss: 0.0233
# Epoch 82/100 | Train Loss: 0.0040 | Val Loss: 0.0233
# Epoch 83/100 | Train Loss: 0.0040 | Val Loss: 0.0232
# Epoch 84/100 | Train Loss: 0.0040 | Val Loss: 0.0232
# Epoch 85/100 | Train Loss: 0.0040 | Val Loss: 0.0235
# Epoch 86/100 | Train Loss: 0.0039 | Val Loss: 0.0232
# Epoch 87/100 | Train Loss: 0.0040 | Val Loss: 0.0232
# Epoch 88/100 | Train Loss: 0.0040 | Val Loss: 0.0234
# Epoch 89/100 | Train Loss: 0.0040 | Val Loss: 0.0232
# Epoch 90/100 | Train Loss: 0.0039 | Val Loss: 0.0232
# Epoch 91/100 | Train Loss: 0.0039 | Val Loss: 0.0230
# Epoch 92/100 | Train Loss: 0.0039 | Val Loss: 0.0231
# Epoch 93/100 | Train Loss: 0.0039 | Val Loss: 0.0233
# Epoch 94/100 | Train Loss: 0.0039 | Val Loss: 0.0233
# Epoch 95/100 | Train Loss: 0.0039 | Val Loss: 0.0233
# Epoch 96/100 | Train Loss: 0.0039 | Val Loss: 0.0234
# Epoch 97/100 | Train Loss: 0.0039 | Val Loss: 0.0233
# Epoch 98/100 | Train Loss: 0.0039 | Val Loss: 0.0234
# Epoch 99/100 | Train Loss: 0.0039 | Val Loss: 0.0233
# Epoch 100/100 | Train Loss: 0.0039 | Val Loss: 0.0233

# %%
torch.save(model.state_dict(), "../../models/value_network/{}.pth".format(model_name.upper()))
