# %%
from data_manager import write_lmdb

# %%
write_lmdb()
# Out:
# Znaleziono plików PGN: 79
# Zapisano: 10000
# Zapisano: 20000
# Zapisano: 30000
# Zapisano: 40000
# Zapisano: 50000
# Zapisano: 60000
# Zapisano: 70000
# Zapisano: 80000
# Zapisano: 90000
# Zapisano: 100000
# Zapisano: 110000
# Zapisano: 120000
# Zapisano: 130000
# Zapisano: 140000
# Zapisano: 150000
# Zapisano: 160000
# Zapisano: 170000
# Zapisano: 180000
# Zapisano: 190000
# Zapisano: 200000
# Zapisano: 210000
# Zapisano: 220000
# Zapisano: 230000
# Zapisano: 240000
# Zapisano: 250000
# Zapisano: 260000
# Zapisano: 270000
# Zapisano: 280000
# Zapisano: 290000
# Zapisano: 300000
# Zapisano: 310000
# Zapisano: 320000
# Zapisano: 330000
# Zapisano: 340000
# Zapisano: 350000
# Zapisano: 360000
# Zapisano: 370000
# Zapisano: 380000
# Zapisano: 390000
# Zapisano: 400000
# Zapisano: 410000
# Zapisano: 420000
# Zapisano: 430000
# Zapisano: 440000
# Zapisano: 450000
# Zapisano: 460000
# Zapisano: 470000
# Zapisano: 480000
# Zapisano: 490000
# Zapisano: 500000
# Zapisano: 510000
# ...
